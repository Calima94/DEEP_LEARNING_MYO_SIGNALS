# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
import os, os.path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from torch.utils.data import Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class EMGDataset(Dataset):
    def __init__(self, folder_path, window_size, moving_avg_delay):
        self.folder_path = folder_path
        self.window_size = window_size
        self.moving_avg_delay = moving_avg_delay
        self.X, self.Y = self.load_and_label()

    def load_and_label(self):
        X = []
        Y = []
        for root, _, files in os.walk(self.folder_path):
            for file in files:
                # Check if the file is a text file (e.g., .txt, .csv)
                if not file.endswith(('.txt', '.csv')):  # Add other relevant extensions if needed
                    continue  # Skip non-text files

                # Load EMG data using NumPy, specifying the encoding
                with open(os.path.join(root, file), 'r', encoding='latin-1') as f:  # or 'cp1252'
                    emg_data = np.loadtxt(f, delimiter='\t')  # Assuming tab-delimited

                for k in range(0, emg_data.shape[0] - self.window_size + 1, self.window_size):
                    d = emg_data[k : k + self.window_size, :]
                    d = np.abs(d)
                    for n in range(d.shape[1] - 1):
                        d[:, n] = np.convolve(d[:, n], np.ones(self.moving_avg_delay) / self.moving_avg_delay, mode='same')
                    X.append(d)
                    label = int(file.split(".")[0])
                    Y.append(label)

        X = np.array(X)
        X = X / np.max(X)  # Normalize
        Y = np.array(Y)
        Y = self.to_one_hot(Y)
        return torch.tensor(X, dtype=torch.float32), torch.tensor(Y, dtype=torch.float32)

    def to_one_hot(self, Y):
        num_classes = np.max(Y) + 1
        one_hot = np.zeros((len(Y), num_classes))
        one_hot[np.arange(len(Y)), Y] = 1
        return one_hot

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx]

# %%
# Example usage
folder_path = "/content/drive/MyDrive/EMG hand gestures dataset"
window_size = 200
moving_avg_delay = 20

dataset = EMGDataset(folder_path, window_size, moving_avg_delay)

# Manually split into train and test sets (replace with your desired method)
data_len = len(dataset)
indices = list(range(data_len))
np.random.shuffle(indices)  # Shuffle indices

train_size = int(0.8 * data_len)
train_indices = indices[:train_size]
test_indices = indices[train_size:]

train_dataset = torch.utils.data.Subset(dataset, train_indices)
test_dataset = torch.utils.data.Subset(dataset, test_indices)

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False)

# %%
class EMGModel(nn.Module):
    def __init__(self):
        super(EMGModel, self).__init__()
        self.fc1 = nn.Linear(200 * 4, 32)  # Input: 200 time steps * 4 channels
        self.tanh1 = nn.Tanh()
        self.lstm = nn.LSTM(32, 16, batch_first=True)  # Input: 32 features from fc1
        self.fc2 = nn.Linear(16, 32)  # Input: 16 features from LSTM
        self.tanh2 = nn.Tanh()
        self.fc3 = nn.Linear(32, 5)  # Output: 5 classes
        self.softmax = nn.Softmax(dim=1)  # Softmax activation for output

    def forward(self, x):
        batch_size = x.shape[0]
        x = x.view(batch_size, -1)
        #x = x.view(batch_size, -1)  # Flatten input to (batch_size, 200*4)
        x = self.tanh1(self.fc1(x))

        # Reshape for LSTM: (batch_size, sequence_length, input_size)
        # Assuming sequence_length = 1 for now (you might need to adjust this)
        x = x.view(batch_size, 1, -1)

        # Pass through LSTM and get the output
        x, _ = self.lstm(x)

        # Take the output from the last time step (since sequence_length = 1)
        x = x[:, -1, :]

        x = self.tanh2(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
def validate(model, test_loader, criterion):
    model.eval()  # Set the model to evaluation mode
    total_loss = 0
    correct = 0
    with torch.no_grad():  # Disable gradient calculation
        for data, target in test_loader:
            output = model(data)
            loss = criterion(output, target)
            total_loss += loss.item()
            pred = output.argmax(dim=1, keepdim=True)  # Get predicted class
            actual_class_indices = torch.argmax(target, dim=1)
            correct += pred.eq(actual_class_indices.view_as(pred)).sum().item()

    avg_loss = total_loss / len(test_loader)
    accuracy = 100. * correct / len(test_loader.dataset)
    return avg_loss, accuracy

# %%
# Instantiate the model, optimizer, and loss function
model = EMGModel()
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()
train_losses = []
val_losses = []
# Training loop
for epoch in range(1000):
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad()  # Reset gradients
        output = model(data)  # Forward pass
        loss = criterion(output, target) # Calculate loss, convert target to long
        loss.backward()  # Backpropagate
        optimizer.step()  # Update weights

    # Validation

    val_loss, val_accuracy = validate(model, test_loader, criterion)
    print(f"Epoch {epoch}: Val Loss = {val_loss:.4f}, Val Accuracy = {val_accuracy:.2f}%")

    # Append losses
    train_losses.append(loss.item()) # Append training loss for current batch
    val_losses.append(val_loss)

# Add EMGModel to safe globals
torch.serialization.add_safe_globals([EMGModel])
# Out:
# Epoch 0: Val Loss = 1.5806, Val Accuracy = 36.02%
# Epoch 1: Val Loss = 1.5375, Val Accuracy = 22.95%
# Epoch 2: Val Loss = 1.4595, Val Accuracy = 48.11%
# Epoch 3: Val Loss = 1.3332, Val Accuracy = 59.34%
# Epoch 4: Val Loss = 1.1703, Val Accuracy = 65.20%
# Epoch 5: Val Loss = 1.0196, Val Accuracy = 68.99%
# Epoch 6: Val Loss = 0.8997, Val Accuracy = 72.28%
# Epoch 7: Val Loss = 0.8037, Val Accuracy = 77.53%
# Epoch 8: Val Loss = 0.7119, Val Accuracy = 78.27%
# Epoch 9: Val Loss = 0.6332, Val Accuracy = 80.22%
# Epoch 10: Val Loss = 0.5647, Val Accuracy = 80.71%
# Epoch 11: Val Loss = 0.5134, Val Accuracy = 82.17%
# Epoch 12: Val Loss = 0.4738, Val Accuracy = 83.39%
# Epoch 13: Val Loss = 0.4459, Val Accuracy = 84.86%
# Epoch 14: Val Loss = 0.4279, Val Accuracy = 86.08%
# Epoch 15: Val Loss = 0.4143, Val Accuracy = 85.96%
# Epoch 16: Val Loss = 0.3949, Val Accuracy = 86.20%
# Epoch 17: Val Loss = 0.3856, Val Accuracy = 87.30%
# Epoch 18: Val Loss = 0.3866, Val Accuracy = 86.32%
# Epoch 19: Val Loss = 0.3686, Val Accuracy = 87.06%
# Epoch 20: Val Loss = 0.3683, Val Accuracy = 86.69%
# Epoch 21: Val Loss = 0.3597, Val Accuracy = 85.96%
# Epoch 22: Val Loss = 0.3535, Val Accuracy = 86.57%
# Epoch 23: Val Loss = 0.3515, Val Accuracy = 86.57%
# Epoch 24: Val Loss = 0.3469, Val Accuracy = 86.32%
# Epoch 25: Val Loss = 0.3450, Val Accuracy = 86.69%
# Epoch 26: Val Loss = 0.3402, Val Accuracy = 86.45%
# Epoch 27: Val Loss = 0.3379, Val Accuracy = 87.30%
# Epoch 28: Val Loss = 0.3457, Val Accuracy = 87.30%
# Epoch 29: Val Loss = 0.3319, Val Accuracy = 87.55%
# Epoch 30: Val Loss = 0.3340, Val Accuracy = 87.06%
# Epoch 31: Val Loss = 0.3305, Val Accuracy = 87.30%
# Epoch 32: Val Loss = 0.3441, Val Accuracy = 87.06%
# Epoch 33: Val Loss = 0.3207, Val Accuracy = 88.03%
# Epoch 34: Val Loss = 0.3217, Val Accuracy = 87.67%
# Epoch 35: Val Loss = 0.3138, Val Accuracy = 88.16%
# Epoch 36: Val Loss = 0.3097, Val Accuracy = 87.67%
# Epoch 37: Val Loss = 0.3236, Val Accuracy = 87.55%
# Epoch 38: Val Loss = 0.3145, Val Accuracy = 87.79%
# Epoch 39: Val Loss = 0.3062, Val Accuracy = 88.52%
# Epoch 40: Val Loss = 0.3059, Val Accuracy = 87.91%
# Epoch 41: Val Loss = 0.3084, Val Accuracy = 88.03%
# Epoch 42: Val Loss = 0.2997, Val Accuracy = 88.28%
# Epoch 43: Val Loss = 0.2940, Val Accuracy = 88.77%
# Epoch 44: Val Loss = 0.2935, Val Accuracy = 88.77%
# Epoch 45: Val Loss = 0.2953, Val Accuracy = 88.64%
# Epoch 46: Val Loss = 0.3248, Val Accuracy = 88.03%
# Epoch 47: Val Loss = 0.2910, Val Accuracy = 88.64%
# Epoch 48: Val Loss = 0.2960, Val Accuracy = 89.01%
# Epoch 49: Val Loss = 0.2890, Val Accuracy = 89.01%
# Epoch 50: Val Loss = 0.2825, Val Accuracy = 88.77%
# Epoch 51: Val Loss = 0.2750, Val Accuracy = 88.89%
# Epoch 52: Val Loss = 0.2827, Val Accuracy = 89.50%
# Epoch 53: Val Loss = 0.2756, Val Accuracy = 89.38%
# Epoch 54: Val Loss = 0.2721, Val Accuracy = 88.77%
# Epoch 55: Val Loss = 0.2692, Val Accuracy = 89.62%
# Epoch 56: Val Loss = 0.2740, Val Accuracy = 90.11%
# Epoch 57: Val Loss = 0.2681, Val Accuracy = 89.38%
# Epoch 58: Val Loss = 0.2739, Val Accuracy = 89.62%
# Epoch 59: Val Loss = 0.2638, Val Accuracy = 88.89%
# Epoch 60: Val Loss = 0.3099, Val Accuracy = 89.26%
# Epoch 61: Val Loss = 0.2580, Val Accuracy = 89.26%
# Epoch 62: Val Loss = 0.2690, Val Accuracy = 90.11%
# Epoch 63: Val Loss = 0.2871, Val Accuracy = 89.26%
# Epoch 64: Val Loss = 0.2564, Val Accuracy = 89.87%
# Epoch 65: Val Loss = 0.2566, Val Accuracy = 89.62%
# Epoch 66: Val Loss = 0.2644, Val Accuracy = 89.74%
# Epoch 67: Val Loss = 0.2511, Val Accuracy = 89.62%
# Epoch 68: Val Loss = 0.2723, Val Accuracy = 89.87%
# Epoch 69: Val Loss = 0.2522, Val Accuracy = 89.87%
# Epoch 70: Val Loss = 0.2566, Val Accuracy = 89.87%
# Epoch 71: Val Loss = 0.2576, Val Accuracy = 89.99%
# Epoch 72: Val Loss = 0.2559, Val Accuracy = 89.74%
# Epoch 73: Val Loss = 0.2664, Val Accuracy = 89.50%
# Epoch 74: Val Loss = 0.2684, Val Accuracy = 89.38%
# Epoch 75: Val Loss = 0.2565, Val Accuracy = 89.50%
# Epoch 76: Val Loss = 0.2618, Val Accuracy = 89.99%
# Epoch 77: Val Loss = 0.2613, Val Accuracy = 89.87%
# Epoch 78: Val Loss = 0.2734, Val Accuracy = 89.38%
# Epoch 79: Val Loss = 0.2539, Val Accuracy = 89.62%
# Epoch 80: Val Loss = 0.2983, Val Accuracy = 89.38%
# Epoch 81: Val Loss = 0.2478, Val Accuracy = 88.89%
# Epoch 82: Val Loss = 0.2548, Val Accuracy = 90.11%
# Epoch 83: Val Loss = 0.2665, Val Accuracy = 89.74%
# Epoch 84: Val Loss = 0.2570, Val Accuracy = 89.01%
# Epoch 85: Val Loss = 0.2758, Val Accuracy = 89.01%
# Epoch 86: Val Loss = 0.2524, Val Accuracy = 89.74%
# Epoch 87: Val Loss = 0.3036, Val Accuracy = 89.13%
# Epoch 88: Val Loss = 0.2510, Val Accuracy = 89.13%
# Epoch 89: Val Loss = 0.2909, Val Accuracy = 89.13%
# Epoch 90: Val Loss = 0.2610, Val Accuracy = 89.74%
# Epoch 91: Val Loss = 0.2560, Val Accuracy = 89.38%
# Epoch 92: Val Loss = 0.2745, Val Accuracy = 89.50%
# Epoch 93: Val Loss = 0.2645, Val Accuracy = 89.62%
# Epoch 94: Val Loss = 0.2580, Val Accuracy = 89.38%
# Epoch 95: Val Loss = 0.2655, Val Accuracy = 89.38%
# Epoch 96: Val Loss = 0.2630, Val Accuracy = 89.38%
# Epoch 97: Val Loss = 0.2706, Val Accuracy = 89.50%
# Epoch 98: Val Loss = 0.2700, Val Accuracy = 89.26%
# Epoch 99: Val Loss = 0.2772, Val Accuracy = 89.26%
# Epoch 100: Val Loss = 0.2657, Val Accuracy = 89.50%
# Epoch 101: Val Loss = 0.2724, Val Accuracy = 89.38%
# Epoch 102: Val Loss = 0.2817, Val Accuracy = 89.50%
# Epoch 103: Val Loss = 0.2924, Val Accuracy = 89.01%
# Epoch 104: Val Loss = 0.2692, Val Accuracy = 89.62%
# Epoch 105: Val Loss = 0.2877, Val Accuracy = 89.01%
# Epoch 106: Val Loss = 0.2915, Val Accuracy = 89.01%
# Epoch 107: Val Loss = 0.2843, Val Accuracy = 89.26%
# Epoch 108: Val Loss = 0.2772, Val Accuracy = 89.50%
# Epoch 109: Val Loss = 0.2794, Val Accuracy = 89.50%
# Epoch 110: Val Loss = 0.2905, Val Accuracy = 89.50%
# Epoch 111: Val Loss = 0.3215, Val Accuracy = 89.38%
# Epoch 112: Val Loss = 0.2926, Val Accuracy = 89.50%
# Epoch 113: Val Loss = 0.2869, Val Accuracy = 89.26%
# Epoch 114: Val Loss = 0.3012, Val Accuracy = 89.62%
# Epoch 115: Val Loss = 0.2999, Val Accuracy = 89.38%
# Epoch 116: Val Loss = 0.2926, Val Accuracy = 89.50%
# Epoch 117: Val Loss = 0.3106, Val Accuracy = 89.74%
# Epoch 118: Val Loss = 0.2968, Val Accuracy = 89.62%
# Epoch 119: Val Loss = 0.3132, Val Accuracy = 89.50%
# Epoch 120: Val Loss = 0.2972, Val Accuracy = 89.62%
# Epoch 121: Val Loss = 0.3171, Val Accuracy = 89.26%
# Epoch 122: Val Loss = 0.3254, Val Accuracy = 89.26%
# Epoch 123: Val Loss = 0.3030, Val Accuracy = 89.62%
# Epoch 124: Val Loss = 0.3091, Val Accuracy = 89.87%
# Epoch 125: Val Loss = 0.3277, Val Accuracy = 89.87%
# Epoch 126: Val Loss = 0.3302, Val Accuracy = 89.62%
# Epoch 127: Val Loss = 0.3337, Val Accuracy = 89.99%
# Epoch 128: Val Loss = 0.3173, Val Accuracy = 89.99%
# Epoch 129: Val Loss = 0.3237, Val Accuracy = 89.87%
# Epoch 130: Val Loss = 0.3259, Val Accuracy = 89.50%
# Epoch 131: Val Loss = 0.3426, Val Accuracy = 89.62%
# Epoch 132: Val Loss = 0.3461, Val Accuracy = 89.62%
# Epoch 133: Val Loss = 0.3317, Val Accuracy = 88.52%
# Epoch 134: Val Loss = 0.3327, Val Accuracy = 89.62%
# Epoch 135: Val Loss = 0.3610, Val Accuracy = 90.11%
# Epoch 136: Val Loss = 0.3310, Val Accuracy = 89.50%
# Epoch 137: Val Loss = 0.3612, Val Accuracy = 89.74%
# Epoch 138: Val Loss = 0.3589, Val Accuracy = 90.23%
# Epoch 139: Val Loss = 0.3562, Val Accuracy = 89.62%
# Epoch 140: Val Loss = 0.3637, Val Accuracy = 89.74%
# Epoch 141: Val Loss = 0.3764, Val Accuracy = 89.87%
# Epoch 142: Val Loss = 0.3477, Val Accuracy = 89.38%
# Epoch 143: Val Loss = 0.3438, Val Accuracy = 89.26%
# Epoch 144: Val Loss = 0.3593, Val Accuracy = 89.26%
# Epoch 145: Val Loss = 0.3724, Val Accuracy = 89.62%
# Epoch 146: Val Loss = 0.3766, Val Accuracy = 89.26%
# Epoch 147: Val Loss = 0.3675, Val Accuracy = 89.50%
# Epoch 148: Val Loss = 0.3748, Val Accuracy = 89.38%
# Epoch 149: Val Loss = 0.3597, Val Accuracy = 89.38%
# Epoch 150: Val Loss = 0.3899, Val Accuracy = 89.01%
# Epoch 151: Val Loss = 0.3749, Val Accuracy = 89.01%
# Epoch 152: Val Loss = 0.3781, Val Accuracy = 89.01%
# Epoch 153: Val Loss = 0.3697, Val Accuracy = 89.26%
# Epoch 154: Val Loss = 0.3714, Val Accuracy = 89.38%
# Epoch 155: Val Loss = 0.3884, Val Accuracy = 89.87%
# Epoch 156: Val Loss = 0.3863, Val Accuracy = 89.01%
# Epoch 157: Val Loss = 0.3844, Val Accuracy = 88.89%
# Epoch 158: Val Loss = 0.3793, Val Accuracy = 89.50%
# Epoch 159: Val Loss = 0.4016, Val Accuracy = 89.50%
# Epoch 160: Val Loss = 0.3778, Val Accuracy = 89.50%
# Epoch 161: Val Loss = 0.4115, Val Accuracy = 89.13%
# Epoch 162: Val Loss = 0.3885, Val Accuracy = 89.62%
# Epoch 163: Val Loss = 0.4060, Val Accuracy = 89.13%
# Epoch 164: Val Loss = 0.4046, Val Accuracy = 89.62%
# Epoch 165: Val Loss = 0.4083, Val Accuracy = 89.38%
# Epoch 166: Val Loss = 0.4307, Val Accuracy = 89.38%
# Epoch 167: Val Loss = 0.4081, Val Accuracy = 89.50%
# Epoch 168: Val Loss = 0.4121, Val Accuracy = 89.38%
# Epoch 169: Val Loss = 0.4131, Val Accuracy = 89.26%
# Epoch 170: Val Loss = 0.4331, Val Accuracy = 88.64%
# Epoch 171: Val Loss = 0.4284, Val Accuracy = 89.13%
# Epoch 172: Val Loss = 0.4269, Val Accuracy = 89.01%
# Epoch 173: Val Loss = 0.4368, Val Accuracy = 89.38%
# Epoch 174: Val Loss = 0.4367, Val Accuracy = 89.50%
# Epoch 175: Val Loss = 0.4344, Val Accuracy = 89.38%
# Epoch 176: Val Loss = 0.4509, Val Accuracy = 89.26%
# Epoch 177: Val Loss = 0.4568, Val Accuracy = 89.26%
# Epoch 178: Val Loss = 0.4719, Val Accuracy = 89.38%
# Epoch 179: Val Loss = 0.4539, Val Accuracy = 89.01%
# Epoch 180: Val Loss = 0.4585, Val Accuracy = 89.38%
# Epoch 181: Val Loss = 0.4751, Val Accuracy = 88.52%
# Epoch 182: Val Loss = 0.4762, Val Accuracy = 88.52%
# Epoch 183: Val Loss = 0.4784, Val Accuracy = 89.13%
# Epoch 184: Val Loss = 0.4695, Val Accuracy = 89.13%
# Epoch 185: Val Loss = 0.5041, Val Accuracy = 89.13%
# Epoch 186: Val Loss = 0.5148, Val Accuracy = 89.13%
# Epoch 187: Val Loss = 0.4956, Val Accuracy = 88.64%
# Epoch 188: Val Loss = 0.4888, Val Accuracy = 88.52%
# Epoch 189: Val Loss = 0.5084, Val Accuracy = 88.89%
# Epoch 190: Val Loss = 0.5047, Val Accuracy = 88.64%
# Epoch 191: Val Loss = 0.5074, Val Accuracy = 88.89%
# Epoch 192: Val Loss = 0.4970, Val Accuracy = 89.01%
# Epoch 193: Val Loss = 0.5139, Val Accuracy = 88.89%
# Epoch 194: Val Loss = 0.5389, Val Accuracy = 88.28%
# Epoch 195: Val Loss = 0.5230, Val Accuracy = 88.52%
# Epoch 196: Val Loss = 0.5199, Val Accuracy = 88.77%
# Epoch 197: Val Loss = 0.5167, Val Accuracy = 89.01%
# Epoch 198: Val Loss = 0.5254, Val Accuracy = 88.89%
# Epoch 199: Val Loss = 0.5315, Val Accuracy = 88.52%
# Epoch 200: Val Loss = 0.5523, Val Accuracy = 88.52%
# Epoch 201: Val Loss = 0.5393, Val Accuracy = 88.52%
# Epoch 202: Val Loss = 0.5482, Val Accuracy = 88.52%
# Epoch 203: Val Loss = 0.5368, Val Accuracy = 88.77%
# Epoch 204: Val Loss = 0.5409, Val Accuracy = 88.77%
# Epoch 205: Val Loss = 0.5507, Val Accuracy = 88.52%
# Epoch 206: Val Loss = 0.5525, Val Accuracy = 88.40%
# Epoch 207: Val Loss = 0.5573, Val Accuracy = 88.52%
# Epoch 208: Val Loss = 0.5691, Val Accuracy = 88.64%
# Epoch 209: Val Loss = 0.5684, Val Accuracy = 88.64%
# Epoch 210: Val Loss = 0.5611, Val Accuracy = 88.77%
# Epoch 211: Val Loss = 0.5755, Val Accuracy = 88.16%
# Epoch 212: Val Loss = 0.5647, Val Accuracy = 88.77%
# Epoch 213: Val Loss = 0.5817, Val Accuracy = 88.52%
# Epoch 214: Val Loss = 0.5872, Val Accuracy = 88.52%
# Epoch 215: Val Loss = 0.5890, Val Accuracy = 88.16%
# Epoch 216: Val Loss = 0.5906, Val Accuracy = 88.40%
# Epoch 217: Val Loss = 0.6103, Val Accuracy = 88.40%
# Epoch 218: Val Loss = 0.5988, Val Accuracy = 88.40%
# Epoch 219: Val Loss = 0.6056, Val Accuracy = 88.28%
# Epoch 220: Val Loss = 0.6014, Val Accuracy = 88.64%
# Epoch 221: Val Loss = 0.6075, Val Accuracy = 88.40%
# Epoch 222: Val Loss = 0.6174, Val Accuracy = 88.03%
# Epoch 223: Val Loss = 0.6167, Val Accuracy = 88.28%
# Epoch 224: Val Loss = 0.6199, Val Accuracy = 88.28%
# Epoch 225: Val Loss = 0.6175, Val Accuracy = 88.52%
# Epoch 226: Val Loss = 0.6244, Val Accuracy = 88.28%
# Epoch 227: Val Loss = 0.6233, Val Accuracy = 88.52%
# Epoch 228: Val Loss = 0.6268, Val Accuracy = 88.40%
# Epoch 229: Val Loss = 0.6282, Val Accuracy = 88.40%
# Epoch 230: Val Loss = 0.6301, Val Accuracy = 88.52%
# Epoch 231: Val Loss = 0.6266, Val Accuracy = 88.64%
# Epoch 232: Val Loss = 0.6382, Val Accuracy = 88.64%
# Epoch 233: Val Loss = 0.6408, Val Accuracy = 88.52%
# Epoch 234: Val Loss = 0.6408, Val Accuracy = 88.64%
# Epoch 235: Val Loss = 0.6515, Val Accuracy = 88.52%
# Epoch 236: Val Loss = 0.6465, Val Accuracy = 88.77%
# Epoch 237: Val Loss = 0.6579, Val Accuracy = 88.64%
# Epoch 238: Val Loss = 0.6514, Val Accuracy = 88.64%
# Epoch 239: Val Loss = 0.6616, Val Accuracy = 88.40%
# Epoch 240: Val Loss = 0.6585, Val Accuracy = 88.64%
# Epoch 241: Val Loss = 0.6603, Val Accuracy = 88.64%
# Epoch 242: Val Loss = 0.6650, Val Accuracy = 88.52%
# Epoch 243: Val Loss = 0.6654, Val Accuracy = 88.52%
# Epoch 244: Val Loss = 0.6778, Val Accuracy = 88.28%
# Epoch 245: Val Loss = 0.6846, Val Accuracy = 88.40%
# Epoch 246: Val Loss = 0.6838, Val Accuracy = 88.64%
# Epoch 247: Val Loss = 0.6802, Val Accuracy = 88.40%
# Epoch 248: Val Loss = 0.6780, Val Accuracy = 88.64%
# Epoch 249: Val Loss = 0.6746, Val Accuracy = 88.77%
# Epoch 250: Val Loss = 0.6882, Val Accuracy = 88.52%
# Epoch 251: Val Loss = 0.6940, Val Accuracy = 88.77%
# Epoch 252: Val Loss = 0.6925, Val Accuracy = 88.40%
# Epoch 253: Val Loss = 0.7010, Val Accuracy = 88.40%
# Epoch 254: Val Loss = 0.6950, Val Accuracy = 88.64%
# Epoch 255: Val Loss = 0.6948, Val Accuracy = 88.52%
# Epoch 256: Val Loss = 0.7069, Val Accuracy = 88.64%
# Epoch 257: Val Loss = 0.7000, Val Accuracy = 88.40%
# Epoch 258: Val Loss = 0.7131, Val Accuracy = 88.64%
# Epoch 259: Val Loss = 0.7038, Val Accuracy = 88.52%
# Epoch 260: Val Loss = 0.7049, Val Accuracy = 88.64%
# Epoch 261: Val Loss = 0.7304, Val Accuracy = 88.52%
# Epoch 262: Val Loss = 0.7159, Val Accuracy = 88.40%
# Epoch 263: Val Loss = 0.7222, Val Accuracy = 88.40%
# Epoch 264: Val Loss = 0.7128, Val Accuracy = 88.89%
# Epoch 265: Val Loss = 0.7329, Val Accuracy = 88.77%
# Epoch 266: Val Loss = 0.7125, Val Accuracy = 88.52%
# Epoch 267: Val Loss = 0.7198, Val Accuracy = 88.89%
# Epoch 268: Val Loss = 0.7338, Val Accuracy = 88.64%
# Epoch 269: Val Loss = 0.7319, Val Accuracy = 88.77%
# Epoch 270: Val Loss = 0.7373, Val Accuracy = 88.64%
# Epoch 271: Val Loss = 0.7242, Val Accuracy = 88.89%
# Epoch 272: Val Loss = 0.7327, Val Accuracy = 88.64%
# Epoch 273: Val Loss = 0.7438, Val Accuracy = 88.40%
# Epoch 274: Val Loss = 0.7355, Val Accuracy = 88.40%
# Epoch 275: Val Loss = 0.7444, Val Accuracy = 88.64%
# Epoch 276: Val Loss = 0.7380, Val Accuracy = 88.40%
# Epoch 277: Val Loss = 0.7519, Val Accuracy = 88.64%
# Epoch 278: Val Loss = 0.7360, Val Accuracy = 88.64%
# Epoch 279: Val Loss = 0.7602, Val Accuracy = 88.77%
# Epoch 280: Val Loss = 0.7456, Val Accuracy = 88.64%
# Epoch 281: Val Loss = 0.7590, Val Accuracy = 88.52%
# Epoch 282: Val Loss = 0.7490, Val Accuracy = 88.52%
# Epoch 283: Val Loss = 0.7558, Val Accuracy = 88.52%
# Epoch 284: Val Loss = 0.7536, Val Accuracy = 88.52%
# Epoch 285: Val Loss = 0.7619, Val Accuracy = 88.52%
# Epoch 286: Val Loss = 0.7590, Val Accuracy = 88.52%
# Epoch 287: Val Loss = 0.7612, Val Accuracy = 88.64%
# Epoch 288: Val Loss = 0.7598, Val Accuracy = 88.52%
# Epoch 289: Val Loss = 0.7668, Val Accuracy = 88.52%
# Epoch 290: Val Loss = 0.7646, Val Accuracy = 88.40%
# Epoch 291: Val Loss = 0.7674, Val Accuracy = 88.52%
# Epoch 292: Val Loss = 0.7715, Val Accuracy = 88.40%
# Epoch 293: Val Loss = 0.7744, Val Accuracy = 88.64%
# Epoch 294: Val Loss = 0.7728, Val Accuracy = 88.64%
# Epoch 295: Val Loss = 0.7768, Val Accuracy = 88.40%
# Epoch 296: Val Loss = 0.7697, Val Accuracy = 88.77%
# Epoch 297: Val Loss = 0.7890, Val Accuracy = 88.64%
# Epoch 298: Val Loss = 0.7872, Val Accuracy = 88.77%
# Epoch 299: Val Loss = 0.7770, Val Accuracy = 88.64%
# Epoch 300: Val Loss = 0.7820, Val Accuracy = 88.52%
# Epoch 301: Val Loss = 0.7858, Val Accuracy = 88.64%
# Epoch 302: Val Loss = 0.7902, Val Accuracy = 88.64%
# Epoch 303: Val Loss = 0.7911, Val Accuracy = 88.64%
# Epoch 304: Val Loss = 0.7871, Val Accuracy = 88.64%
# Epoch 305: Val Loss = 0.8074, Val Accuracy = 88.77%
# Epoch 306: Val Loss = 0.7897, Val Accuracy = 88.52%
# Epoch 307: Val Loss = 0.8058, Val Accuracy = 88.77%
# Epoch 308: Val Loss = 0.7908, Val Accuracy = 88.89%
# Epoch 309: Val Loss = 0.7946, Val Accuracy = 88.64%
# Epoch 310: Val Loss = 0.8002, Val Accuracy = 88.40%
# Epoch 311: Val Loss = 0.8052, Val Accuracy = 88.52%
# Epoch 312: Val Loss = 0.7999, Val Accuracy = 88.52%
# Epoch 313: Val Loss = 0.8022, Val Accuracy = 88.40%
# Epoch 314: Val Loss = 0.8044, Val Accuracy = 88.64%
# Epoch 315: Val Loss = 0.8067, Val Accuracy = 88.64%
# Epoch 316: Val Loss = 0.8089, Val Accuracy = 88.64%
# Epoch 317: Val Loss = 0.8030, Val Accuracy = 88.77%
# Epoch 318: Val Loss = 0.8178, Val Accuracy = 88.64%
# Epoch 319: Val Loss = 0.8117, Val Accuracy = 88.64%
# Epoch 320: Val Loss = 0.8100, Val Accuracy = 88.64%
# Epoch 321: Val Loss = 0.8209, Val Accuracy = 88.52%
# Epoch 322: Val Loss = 0.8168, Val Accuracy = 88.64%
# Epoch 323: Val Loss = 0.8195, Val Accuracy = 88.64%
# Epoch 324: Val Loss = 0.8240, Val Accuracy = 88.64%
# Epoch 325: Val Loss = 0.8231, Val Accuracy = 88.52%
# Epoch 326: Val Loss = 0.8255, Val Accuracy = 88.77%
# Epoch 327: Val Loss = 0.8275, Val Accuracy = 88.64%
# Epoch 328: Val Loss = 0.8233, Val Accuracy = 88.40%
# Epoch 329: Val Loss = 0.8295, Val Accuracy = 88.52%
# Epoch 330: Val Loss = 0.8282, Val Accuracy = 88.52%
# Epoch 331: Val Loss = 0.8310, Val Accuracy = 88.64%
# Epoch 332: Val Loss = 0.8363, Val Accuracy = 88.64%
# Epoch 333: Val Loss = 0.8372, Val Accuracy = 88.77%
# Epoch 334: Val Loss = 0.8327, Val Accuracy = 88.64%
# Epoch 335: Val Loss = 0.8343, Val Accuracy = 88.52%
# Epoch 336: Val Loss = 0.8321, Val Accuracy = 88.40%
# Epoch 337: Val Loss = 0.8351, Val Accuracy = 88.40%
# Epoch 338: Val Loss = 0.8403, Val Accuracy = 88.77%
# Epoch 339: Val Loss = 0.8493, Val Accuracy = 88.77%
# Epoch 340: Val Loss = 0.8475, Val Accuracy = 88.64%
# Epoch 341: Val Loss = 0.8376, Val Accuracy = 88.64%
# Epoch 342: Val Loss = 0.8432, Val Accuracy = 88.52%
# Epoch 343: Val Loss = 0.8457, Val Accuracy = 88.64%
# Epoch 344: Val Loss = 0.8477, Val Accuracy = 88.64%
# Epoch 345: Val Loss = 0.8497, Val Accuracy = 88.64%
# Epoch 346: Val Loss = 0.8464, Val Accuracy = 88.40%
# Epoch 347: Val Loss = 0.8497, Val Accuracy = 88.52%
# Epoch 348: Val Loss = 0.8573, Val Accuracy = 88.64%
# Epoch 349: Val Loss = 0.8567, Val Accuracy = 88.77%
# Epoch 350: Val Loss = 0.8581, Val Accuracy = 88.77%
# Epoch 351: Val Loss = 0.8567, Val Accuracy = 88.64%
# Epoch 352: Val Loss = 0.8550, Val Accuracy = 88.52%
# Epoch 353: Val Loss = 0.8580, Val Accuracy = 88.52%
# Epoch 354: Val Loss = 0.8628, Val Accuracy = 88.77%
# Epoch 355: Val Loss = 0.8590, Val Accuracy = 88.52%
# Epoch 356: Val Loss = 0.8584, Val Accuracy = 88.64%
# Epoch 357: Val Loss = 0.8594, Val Accuracy = 88.64%
# Epoch 358: Val Loss = 0.8600, Val Accuracy = 88.40%
# Epoch 359: Val Loss = 0.8629, Val Accuracy = 88.52%
# Epoch 360: Val Loss = 0.8671, Val Accuracy = 88.64%
# Epoch 361: Val Loss = 0.8655, Val Accuracy = 88.77%
# Epoch 362: Val Loss = 0.8668, Val Accuracy = 88.64%
# Epoch 363: Val Loss = 0.8707, Val Accuracy = 88.64%
# Epoch 364: Val Loss = 0.8771, Val Accuracy = 88.77%
# Epoch 365: Val Loss = 0.8698, Val Accuracy = 88.52%
# Epoch 366: Val Loss = 0.8784, Val Accuracy = 88.89%
# Epoch 367: Val Loss = 0.8773, Val Accuracy = 88.64%
# Epoch 368: Val Loss = 0.8725, Val Accuracy = 88.52%
# Epoch 369: Val Loss = 0.8813, Val Accuracy = 88.77%
# Epoch 370: Val Loss = 0.8900, Val Accuracy = 88.89%
# Epoch 371: Val Loss = 0.8861, Val Accuracy = 88.77%
# Epoch 372: Val Loss = 0.8826, Val Accuracy = 88.77%
# Epoch 373: Val Loss = 0.8799, Val Accuracy = 88.40%
# Epoch 374: Val Loss = 0.8881, Val Accuracy = 88.64%
# Epoch 375: Val Loss = 0.8855, Val Accuracy = 88.64%
# Epoch 376: Val Loss = 0.8834, Val Accuracy = 88.52%
# Epoch 377: Val Loss = 0.8940, Val Accuracy = 88.77%
# Epoch 378: Val Loss = 0.8942, Val Accuracy = 88.77%
# Epoch 379: Val Loss = 0.8880, Val Accuracy = 88.40%
# Epoch 380: Val Loss = 0.8871, Val Accuracy = 88.40%
# Epoch 381: Val Loss = 0.8892, Val Accuracy = 88.64%
# Epoch 382: Val Loss = 0.8983, Val Accuracy = 88.77%
# Epoch 383: Val Loss = 0.8937, Val Accuracy = 88.40%
# Epoch 384: Val Loss = 0.8927, Val Accuracy = 88.52%
# Epoch 385: Val Loss = 0.8936, Val Accuracy = 88.64%
# Epoch 386: Val Loss = 0.8987, Val Accuracy = 88.77%
# Epoch 387: Val Loss = 0.8975, Val Accuracy = 88.64%
# Epoch 388: Val Loss = 0.9002, Val Accuracy = 88.89%
# Epoch 389: Val Loss = 0.9007, Val Accuracy = 88.64%
# Epoch 390: Val Loss = 0.9030, Val Accuracy = 88.77%
# Epoch 391: Val Loss = 0.9028, Val Accuracy = 88.64%
# Epoch 392: Val Loss = 0.9039, Val Accuracy = 88.89%
# Epoch 393: Val Loss = 0.9079, Val Accuracy = 88.77%
# Epoch 394: Val Loss = 0.9042, Val Accuracy = 88.77%
# Epoch 395: Val Loss = 0.9049, Val Accuracy = 88.64%
# Epoch 396: Val Loss = 0.9067, Val Accuracy = 88.40%
# Epoch 397: Val Loss = 0.9105, Val Accuracy = 88.77%
# Epoch 398: Val Loss = 0.9154, Val Accuracy = 88.89%
# Epoch 399: Val Loss = 0.9109, Val Accuracy = 88.64%
# Epoch 400: Val Loss = 0.9144, Val Accuracy = 88.77%
# Epoch 401: Val Loss = 0.9149, Val Accuracy = 88.64%
# Epoch 402: Val Loss = 0.9169, Val Accuracy = 88.64%
# Epoch 403: Val Loss = 0.9180, Val Accuracy = 88.89%
# Epoch 404: Val Loss = 0.9184, Val Accuracy = 88.89%
# Epoch 405: Val Loss = 0.9201, Val Accuracy = 88.77%
# Epoch 406: Val Loss = 0.9214, Val Accuracy = 88.77%
# Epoch 407: Val Loss = 0.9207, Val Accuracy = 88.77%
# Epoch 408: Val Loss = 0.9163, Val Accuracy = 88.52%
# Epoch 409: Val Loss = 0.9251, Val Accuracy = 88.89%
# Epoch 410: Val Loss = 0.9298, Val Accuracy = 88.77%
# Epoch 411: Val Loss = 0.9284, Val Accuracy = 88.89%
# Epoch 412: Val Loss = 0.9257, Val Accuracy = 88.89%
# Epoch 413: Val Loss = 0.9277, Val Accuracy = 88.89%
# Epoch 414: Val Loss = 0.9295, Val Accuracy = 88.64%
# Epoch 415: Val Loss = 0.9271, Val Accuracy = 88.64%
# Epoch 416: Val Loss = 0.9347, Val Accuracy = 88.89%
# Epoch 417: Val Loss = 0.9303, Val Accuracy = 88.64%
# Epoch 418: Val Loss = 0.9303, Val Accuracy = 88.52%
# Epoch 419: Val Loss = 0.9276, Val Accuracy = 88.28%
# Epoch 420: Val Loss = 0.9350, Val Accuracy = 88.77%
# Epoch 421: Val Loss = 0.9354, Val Accuracy = 88.64%
# Epoch 422: Val Loss = 0.9346, Val Accuracy = 88.52%
# Epoch 423: Val Loss = 0.9363, Val Accuracy = 88.77%
# Epoch 424: Val Loss = 0.9358, Val Accuracy = 88.52%
# Epoch 425: Val Loss = 0.9346, Val Accuracy = 88.28%
# Epoch 426: Val Loss = 0.9374, Val Accuracy = 88.64%
# Epoch 427: Val Loss = 0.9387, Val Accuracy = 88.64%
# Epoch 428: Val Loss = 0.9409, Val Accuracy = 88.64%
# Epoch 429: Val Loss = 0.9451, Val Accuracy = 88.77%
# Epoch 430: Val Loss = 0.9416, Val Accuracy = 88.64%
# Epoch 431: Val Loss = 0.9444, Val Accuracy = 88.77%
# Epoch 432: Val Loss = 0.9428, Val Accuracy = 88.64%
# Epoch 433: Val Loss = 0.9467, Val Accuracy = 88.77%
# Epoch 434: Val Loss = 0.9440, Val Accuracy = 88.40%
# Epoch 435: Val Loss = 0.9441, Val Accuracy = 88.52%
# Epoch 436: Val Loss = 0.9453, Val Accuracy = 88.64%
# Epoch 437: Val Loss = 0.9507, Val Accuracy = 88.77%
# Epoch 438: Val Loss = 0.9527, Val Accuracy = 88.77%
# Epoch 439: Val Loss = 0.9546, Val Accuracy = 88.77%
# Epoch 440: Val Loss = 0.9549, Val Accuracy = 88.77%
# Epoch 441: Val Loss = 0.9553, Val Accuracy = 88.77%
# Epoch 442: Val Loss = 0.9537, Val Accuracy = 88.64%
# Epoch 443: Val Loss = 0.9543, Val Accuracy = 88.77%
# Epoch 444: Val Loss = 0.9565, Val Accuracy = 88.77%
# Epoch 445: Val Loss = 0.9593, Val Accuracy = 88.64%
# Epoch 446: Val Loss = 0.9594, Val Accuracy = 88.77%
# Epoch 447: Val Loss = 0.9614, Val Accuracy = 88.77%
# Epoch 448: Val Loss = 0.9627, Val Accuracy = 88.77%
# Epoch 449: Val Loss = 0.9617, Val Accuracy = 88.77%
# Epoch 450: Val Loss = 0.9627, Val Accuracy = 88.77%
# Epoch 451: Val Loss = 0.9652, Val Accuracy = 88.77%
# Epoch 452: Val Loss = 0.9659, Val Accuracy = 88.77%
# Epoch 453: Val Loss = 0.9655, Val Accuracy = 88.77%
# Epoch 454: Val Loss = 0.9648, Val Accuracy = 88.77%
# Epoch 455: Val Loss = 0.9697, Val Accuracy = 88.77%
# Epoch 456: Val Loss = 0.9724, Val Accuracy = 88.89%
# Epoch 457: Val Loss = 0.9673, Val Accuracy = 88.52%
# Epoch 458: Val Loss = 0.9728, Val Accuracy = 88.77%
# Epoch 459: Val Loss = 0.9756, Val Accuracy = 88.89%
# Epoch 460: Val Loss = 0.9736, Val Accuracy = 88.89%
# Epoch 461: Val Loss = 0.9751, Val Accuracy = 88.77%
# Epoch 462: Val Loss = 0.9766, Val Accuracy = 88.89%
# Epoch 463: Val Loss = 0.9746, Val Accuracy = 88.77%
# Epoch 464: Val Loss = 0.9762, Val Accuracy = 88.77%
# Epoch 465: Val Loss = 0.9751, Val Accuracy = 88.64%
# Epoch 466: Val Loss = 0.9760, Val Accuracy = 88.52%
# Epoch 467: Val Loss = 0.9805, Val Accuracy = 88.77%
# Epoch 468: Val Loss = 0.9809, Val Accuracy = 88.77%
# Epoch 469: Val Loss = 0.9830, Val Accuracy = 88.77%
# Epoch 470: Val Loss = 0.9853, Val Accuracy = 88.77%
# Epoch 471: Val Loss = 0.9814, Val Accuracy = 88.77%
# Epoch 472: Val Loss = 0.9804, Val Accuracy = 88.40%
# Epoch 473: Val Loss = 0.9827, Val Accuracy = 88.77%
# Epoch 474: Val Loss = 0.9876, Val Accuracy = 88.77%
# Epoch 475: Val Loss = 0.9897, Val Accuracy = 88.89%
# Epoch 476: Val Loss = 0.9924, Val Accuracy = 88.64%
# Epoch 477: Val Loss = 0.9867, Val Accuracy = 88.77%
# Epoch 478: Val Loss = 0.9867, Val Accuracy = 88.64%
# Epoch 479: Val Loss = 0.9911, Val Accuracy = 88.77%
# Epoch 480: Val Loss = 0.9918, Val Accuracy = 88.77%
# Epoch 481: Val Loss = 0.9922, Val Accuracy = 88.64%
# Epoch 482: Val Loss = 0.9929, Val Accuracy = 88.77%
# Epoch 483: Val Loss = 0.9971, Val Accuracy = 88.89%
# Epoch 484: Val Loss = 0.9983, Val Accuracy = 88.89%
# Epoch 485: Val Loss = 0.9974, Val Accuracy = 88.77%
# Epoch 486: Val Loss = 0.9963, Val Accuracy = 88.52%
# Epoch 487: Val Loss = 1.0002, Val Accuracy = 88.77%
# Epoch 488: Val Loss = 0.9979, Val Accuracy = 88.77%
# Epoch 489: Val Loss = 0.9990, Val Accuracy = 88.77%
# Epoch 490: Val Loss = 0.9977, Val Accuracy = 88.52%
# Epoch 491: Val Loss = 1.0028, Val Accuracy = 88.77%
# Epoch 492: Val Loss = 1.0061, Val Accuracy = 89.01%
# Epoch 493: Val Loss = 1.0068, Val Accuracy = 88.52%
# Epoch 494: Val Loss = 1.0074, Val Accuracy = 88.77%
# Epoch 495: Val Loss = 1.0092, Val Accuracy = 88.64%
# Epoch 496: Val Loss = 1.0034, Val Accuracy = 88.77%
# Epoch 497: Val Loss = 1.0068, Val Accuracy = 88.77%
# Epoch 498: Val Loss = 1.0125, Val Accuracy = 88.77%
# Epoch 499: Val Loss = 1.0144, Val Accuracy = 88.77%
# Epoch 500: Val Loss = 1.0119, Val Accuracy = 88.77%
# Epoch 501: Val Loss = 1.0081, Val Accuracy = 88.52%
# Epoch 502: Val Loss = 1.0056, Val Accuracy = 88.64%
# Epoch 503: Val Loss = 1.0119, Val Accuracy = 88.77%
# Epoch 504: Val Loss = 1.0105, Val Accuracy = 88.64%
# Epoch 505: Val Loss = 1.0139, Val Accuracy = 88.64%
# Epoch 506: Val Loss = 1.0114, Val Accuracy = 88.77%
# Epoch 507: Val Loss = 1.0145, Val Accuracy = 88.64%
# Epoch 508: Val Loss = 1.0149, Val Accuracy = 88.64%
# Epoch 509: Val Loss = 1.0138, Val Accuracy = 88.52%
# Epoch 510: Val Loss = 1.0157, Val Accuracy = 88.64%
# Epoch 511: Val Loss = 1.0147, Val Accuracy = 88.52%
# Epoch 512: Val Loss = 1.0183, Val Accuracy = 88.64%
# Epoch 513: Val Loss = 1.0254, Val Accuracy = 88.77%
# Epoch 514: Val Loss = 1.0243, Val Accuracy = 88.64%
# Epoch 515: Val Loss = 1.0278, Val Accuracy = 88.52%
# Epoch 516: Val Loss = 1.0238, Val Accuracy = 88.64%
# Epoch 517: Val Loss = 1.0227, Val Accuracy = 88.64%
# Epoch 518: Val Loss = 1.0202, Val Accuracy = 88.52%
# Epoch 519: Val Loss = 1.0219, Val Accuracy = 88.52%
# Epoch 520: Val Loss = 1.0239, Val Accuracy = 88.64%
# Epoch 521: Val Loss = 1.0234, Val Accuracy = 88.64%
# Epoch 522: Val Loss = 1.0264, Val Accuracy = 88.77%
# Epoch 523: Val Loss = 1.0348, Val Accuracy = 88.52%
# Epoch 524: Val Loss = 1.0300, Val Accuracy = 88.52%
# Epoch 525: Val Loss = 1.0274, Val Accuracy = 88.64%
# Epoch 526: Val Loss = 1.0261, Val Accuracy = 88.52%
# Epoch 527: Val Loss = 1.0273, Val Accuracy = 88.28%
# Epoch 528: Val Loss = 1.0289, Val Accuracy = 88.52%
# Epoch 529: Val Loss = 1.0322, Val Accuracy = 88.77%
# Epoch 530: Val Loss = 1.0303, Val Accuracy = 88.52%
# Epoch 531: Val Loss = 1.0317, Val Accuracy = 88.52%
# Epoch 532: Val Loss = 1.0373, Val Accuracy = 88.77%
# Epoch 533: Val Loss = 1.0435, Val Accuracy = 88.40%
# Epoch 534: Val Loss = 1.0448, Val Accuracy = 88.64%
# Epoch 535: Val Loss = 1.0393, Val Accuracy = 88.64%
# Epoch 536: Val Loss = 1.0426, Val Accuracy = 88.89%
# Epoch 537: Val Loss = 1.0389, Val Accuracy = 88.64%
# Epoch 538: Val Loss = 1.0421, Val Accuracy = 88.77%
# Epoch 539: Val Loss = 1.0424, Val Accuracy = 88.77%
# Epoch 540: Val Loss = 1.0430, Val Accuracy = 88.77%
# Epoch 541: Val Loss = 1.0421, Val Accuracy = 88.64%
# Epoch 542: Val Loss = 1.0455, Val Accuracy = 88.77%
# Epoch 543: Val Loss = 1.0478, Val Accuracy = 88.64%
# Epoch 544: Val Loss = 1.0440, Val Accuracy = 88.64%
# Epoch 545: Val Loss = 1.0480, Val Accuracy = 88.77%
# Epoch 546: Val Loss = 1.0476, Val Accuracy = 88.77%
# Epoch 547: Val Loss = 1.0496, Val Accuracy = 88.77%
# Epoch 548: Val Loss = 1.0490, Val Accuracy = 88.77%
# Epoch 549: Val Loss = 1.0477, Val Accuracy = 88.64%
# Epoch 550: Val Loss = 1.0514, Val Accuracy = 88.77%
# Epoch 551: Val Loss = 1.0513, Val Accuracy = 88.77%
# Epoch 552: Val Loss = 1.0481, Val Accuracy = 88.52%
# Epoch 553: Val Loss = 1.0501, Val Accuracy = 88.64%
# Epoch 554: Val Loss = 1.0526, Val Accuracy = 88.77%
# Epoch 555: Val Loss = 1.0519, Val Accuracy = 88.64%
# Epoch 556: Val Loss = 1.0535, Val Accuracy = 88.77%
# Epoch 557: Val Loss = 1.0598, Val Accuracy = 88.64%
# Epoch 558: Val Loss = 1.0658, Val Accuracy = 88.52%
# Epoch 559: Val Loss = 1.0627, Val Accuracy = 88.52%
# Epoch 560: Val Loss = 1.0618, Val Accuracy = 88.64%
# Epoch 561: Val Loss = 1.0676, Val Accuracy = 88.40%
# Epoch 562: Val Loss = 1.0688, Val Accuracy = 88.40%
# Epoch 563: Val Loss = 1.0691, Val Accuracy = 88.52%
# Epoch 564: Val Loss = 1.0646, Val Accuracy = 88.64%
# Epoch 565: Val Loss = 1.0615, Val Accuracy = 88.77%
# Epoch 566: Val Loss = 1.0655, Val Accuracy = 88.64%
# Epoch 567: Val Loss = 1.0638, Val Accuracy = 88.64%
# Epoch 568: Val Loss = 1.0665, Val Accuracy = 88.77%
# Epoch 569: Val Loss = 1.0663, Val Accuracy = 88.64%
# Epoch 570: Val Loss = 1.0708, Val Accuracy = 88.52%
# Epoch 571: Val Loss = 1.0725, Val Accuracy = 88.52%
# Epoch 572: Val Loss = 1.0757, Val Accuracy = 88.52%
# Epoch 573: Val Loss = 1.0742, Val Accuracy = 88.52%
# Epoch 574: Val Loss = 1.0730, Val Accuracy = 88.52%
# Epoch 575: Val Loss = 1.0694, Val Accuracy = 88.77%
# Epoch 576: Val Loss = 1.0750, Val Accuracy = 88.64%
# Epoch 577: Val Loss = 1.0736, Val Accuracy = 88.64%
# Epoch 578: Val Loss = 1.0734, Val Accuracy = 88.77%
# Epoch 579: Val Loss = 1.0732, Val Accuracy = 88.64%
# Epoch 580: Val Loss = 1.0736, Val Accuracy = 88.77%
# Epoch 581: Val Loss = 1.0780, Val Accuracy = 88.64%
# Epoch 582: Val Loss = 1.0782, Val Accuracy = 88.64%
# Epoch 583: Val Loss = 1.0806, Val Accuracy = 88.52%
# Epoch 584: Val Loss = 1.0808, Val Accuracy = 88.52%
# Epoch 585: Val Loss = 1.0779, Val Accuracy = 88.77%
# Epoch 586: Val Loss = 1.0757, Val Accuracy = 88.64%
# Epoch 587: Val Loss = 1.0780, Val Accuracy = 88.77%
# Epoch 588: Val Loss = 1.0784, Val Accuracy = 88.64%
# Epoch 589: Val Loss = 1.0817, Val Accuracy = 88.77%
# Epoch 590: Val Loss = 1.0835, Val Accuracy = 88.64%
# Epoch 591: Val Loss = 1.0819, Val Accuracy = 88.77%
# Epoch 592: Val Loss = 1.0826, Val Accuracy = 88.64%
# Epoch 593: Val Loss = 1.0847, Val Accuracy = 88.77%
# Epoch 594: Val Loss = 1.0859, Val Accuracy = 88.77%
# Epoch 595: Val Loss = 1.0861, Val Accuracy = 88.77%
# Epoch 596: Val Loss = 1.0896, Val Accuracy = 88.52%
# Epoch 597: Val Loss = 1.0890, Val Accuracy = 88.77%
# Epoch 598: Val Loss = 1.0890, Val Accuracy = 88.77%
# Epoch 599: Val Loss = 1.0933, Val Accuracy = 88.52%
# Epoch 600: Val Loss = 1.0957, Val Accuracy = 88.52%
# Epoch 601: Val Loss = 1.0938, Val Accuracy = 88.52%
# Epoch 602: Val Loss = 1.0965, Val Accuracy = 88.52%
# Epoch 603: Val Loss = 1.0986, Val Accuracy = 88.52%
# Epoch 604: Val Loss = 1.0937, Val Accuracy = 88.77%
# Epoch 605: Val Loss = 1.0982, Val Accuracy = 88.52%
# Epoch 606: Val Loss = 1.0951, Val Accuracy = 88.64%
# Epoch 607: Val Loss = 1.0932, Val Accuracy = 88.64%
# Epoch 608: Val Loss = 1.0935, Val Accuracy = 88.64%
# Epoch 609: Val Loss = 1.0922, Val Accuracy = 88.64%
# Epoch 610: Val Loss = 1.0935, Val Accuracy = 88.64%
# Epoch 611: Val Loss = 1.0972, Val Accuracy = 88.64%
# Epoch 612: Val Loss = 1.0981, Val Accuracy = 88.64%
# Epoch 613: Val Loss = 1.1004, Val Accuracy = 88.64%
# Epoch 614: Val Loss = 1.1023, Val Accuracy = 88.52%
# Epoch 615: Val Loss = 1.1004, Val Accuracy = 88.77%
# Epoch 616: Val Loss = 1.1008, Val Accuracy = 88.64%
# Epoch 617: Val Loss = 1.1028, Val Accuracy = 88.52%
# Epoch 618: Val Loss = 1.1011, Val Accuracy = 88.64%
# Epoch 619: Val Loss = 1.1017, Val Accuracy = 88.64%
# Epoch 620: Val Loss = 1.1029, Val Accuracy = 88.64%
# Epoch 621: Val Loss = 1.1030, Val Accuracy = 88.64%
# Epoch 622: Val Loss = 1.1060, Val Accuracy = 88.52%
# Epoch 623: Val Loss = 1.1049, Val Accuracy = 88.64%
# Epoch 624: Val Loss = 1.1094, Val Accuracy = 88.64%
# Epoch 625: Val Loss = 1.1073, Val Accuracy = 88.64%
# Epoch 626: Val Loss = 1.1094, Val Accuracy = 88.52%
# Epoch 627: Val Loss = 1.1107, Val Accuracy = 88.52%
# Epoch 628: Val Loss = 1.1123, Val Accuracy = 88.64%
# Epoch 629: Val Loss = 1.1118, Val Accuracy = 88.52%
# Epoch 630: Val Loss = 1.1147, Val Accuracy = 88.52%
# Epoch 631: Val Loss = 1.1144, Val Accuracy = 88.64%
# Epoch 632: Val Loss = 1.1116, Val Accuracy = 88.64%
# Epoch 633: Val Loss = 1.1122, Val Accuracy = 88.64%
# Epoch 634: Val Loss = 1.1152, Val Accuracy = 88.52%
# Epoch 635: Val Loss = 1.1179, Val Accuracy = 88.52%
# Epoch 636: Val Loss = 1.1176, Val Accuracy = 88.64%
# Epoch 637: Val Loss = 1.1199, Val Accuracy = 88.52%
# Epoch 638: Val Loss = 1.1202, Val Accuracy = 88.52%
# Epoch 639: Val Loss = 1.1180, Val Accuracy = 88.64%
# Epoch 640: Val Loss = 1.1180, Val Accuracy = 88.64%
# Epoch 641: Val Loss = 1.1189, Val Accuracy = 88.64%
# Epoch 642: Val Loss = 1.1167, Val Accuracy = 88.64%
# Epoch 643: Val Loss = 1.1226, Val Accuracy = 88.52%
# Epoch 644: Val Loss = 1.1221, Val Accuracy = 88.52%
# Epoch 645: Val Loss = 1.1200, Val Accuracy = 88.64%
# Epoch 646: Val Loss = 1.1230, Val Accuracy = 88.64%
# Epoch 647: Val Loss = 1.1225, Val Accuracy = 88.64%
# Epoch 648: Val Loss = 1.1239, Val Accuracy = 88.64%
# Epoch 649: Val Loss = 1.1252, Val Accuracy = 88.64%
# Epoch 650: Val Loss = 1.1260, Val Accuracy = 88.52%
# Epoch 651: Val Loss = 1.1282, Val Accuracy = 88.64%
# Epoch 652: Val Loss = 1.1309, Val Accuracy = 88.52%
# Epoch 653: Val Loss = 1.1321, Val Accuracy = 88.52%
# Epoch 654: Val Loss = 1.1363, Val Accuracy = 88.40%
# Epoch 655: Val Loss = 1.1309, Val Accuracy = 88.64%
# Epoch 656: Val Loss = 1.1303, Val Accuracy = 88.52%
# Epoch 657: Val Loss = 1.1321, Val Accuracy = 88.40%
# Epoch 658: Val Loss = 1.1303, Val Accuracy = 88.64%
# Epoch 659: Val Loss = 1.1319, Val Accuracy = 88.52%
# Epoch 660: Val Loss = 1.1310, Val Accuracy = 88.64%
# Epoch 661: Val Loss = 1.1314, Val Accuracy = 88.64%
# Epoch 662: Val Loss = 1.1303, Val Accuracy = 88.64%
# Epoch 663: Val Loss = 1.1348, Val Accuracy = 88.52%
# Epoch 664: Val Loss = 1.1373, Val Accuracy = 88.40%
# Epoch 665: Val Loss = 1.1381, Val Accuracy = 88.40%
# Epoch 666: Val Loss = 1.1440, Val Accuracy = 88.52%
# Epoch 667: Val Loss = 1.1431, Val Accuracy = 88.52%
# Epoch 668: Val Loss = 1.1436, Val Accuracy = 88.52%
# Epoch 669: Val Loss = 1.1436, Val Accuracy = 88.52%
# Epoch 670: Val Loss = 1.1430, Val Accuracy = 88.52%
# Epoch 671: Val Loss = 1.1411, Val Accuracy = 88.52%
# Epoch 672: Val Loss = 1.1377, Val Accuracy = 88.64%
# Epoch 673: Val Loss = 1.1428, Val Accuracy = 88.64%
# Epoch 674: Val Loss = 1.1488, Val Accuracy = 88.52%
# Epoch 675: Val Loss = 1.1464, Val Accuracy = 88.40%
# Epoch 676: Val Loss = 1.1462, Val Accuracy = 88.52%
# Epoch 677: Val Loss = 1.1460, Val Accuracy = 88.40%
# Epoch 678: Val Loss = 1.1436, Val Accuracy = 88.64%
# Epoch 679: Val Loss = 1.1463, Val Accuracy = 88.52%
# Epoch 680: Val Loss = 1.1466, Val Accuracy = 88.52%
# Epoch 681: Val Loss = 1.1477, Val Accuracy = 88.52%
# Epoch 682: Val Loss = 1.1457, Val Accuracy = 88.64%
# Epoch 683: Val Loss = 1.1492, Val Accuracy = 88.52%
# Epoch 684: Val Loss = 1.1472, Val Accuracy = 88.77%
# Epoch 685: Val Loss = 1.1498, Val Accuracy = 88.64%
# Epoch 686: Val Loss = 1.1504, Val Accuracy = 88.64%
# Epoch 687: Val Loss = 1.1502, Val Accuracy = 88.64%
# Epoch 688: Val Loss = 1.1558, Val Accuracy = 88.52%
# Epoch 689: Val Loss = 1.1548, Val Accuracy = 88.40%
# Epoch 690: Val Loss = 1.1542, Val Accuracy = 88.40%
# Epoch 691: Val Loss = 1.1532, Val Accuracy = 88.77%
# Epoch 692: Val Loss = 1.1529, Val Accuracy = 88.64%
# Epoch 693: Val Loss = 1.1535, Val Accuracy = 88.77%
# Epoch 694: Val Loss = 1.1544, Val Accuracy = 88.77%
# Epoch 695: Val Loss = 1.1563, Val Accuracy = 88.52%
# Epoch 696: Val Loss = 1.1556, Val Accuracy = 88.77%
# Epoch 697: Val Loss = 1.1563, Val Accuracy = 88.77%
# Epoch 698: Val Loss = 1.1571, Val Accuracy = 88.77%
# Epoch 699: Val Loss = 1.1575, Val Accuracy = 88.77%
# Epoch 700: Val Loss = 1.1580, Val Accuracy = 88.77%
# Epoch 701: Val Loss = 1.1608, Val Accuracy = 88.52%
# Epoch 702: Val Loss = 1.1618, Val Accuracy = 88.52%
# Epoch 703: Val Loss = 1.1640, Val Accuracy = 88.40%
# Epoch 704: Val Loss = 1.1656, Val Accuracy = 88.40%
# Epoch 705: Val Loss = 1.1629, Val Accuracy = 88.77%
# Epoch 706: Val Loss = 1.1636, Val Accuracy = 88.52%
# Epoch 707: Val Loss = 1.1647, Val Accuracy = 88.64%
# Epoch 708: Val Loss = 1.1631, Val Accuracy = 88.77%
# Epoch 709: Val Loss = 1.1676, Val Accuracy = 88.40%
# Epoch 710: Val Loss = 1.1681, Val Accuracy = 88.40%
# Epoch 711: Val Loss = 1.1677, Val Accuracy = 88.52%
# Epoch 712: Val Loss = 1.1681, Val Accuracy = 88.52%
# Epoch 713: Val Loss = 1.1688, Val Accuracy = 88.77%
# Epoch 714: Val Loss = 1.1717, Val Accuracy = 88.40%
# Epoch 715: Val Loss = 1.1737, Val Accuracy = 88.52%
# Epoch 716: Val Loss = 1.1715, Val Accuracy = 88.40%
# Epoch 717: Val Loss = 1.1713, Val Accuracy = 88.52%
# Epoch 718: Val Loss = 1.1714, Val Accuracy = 88.77%
# Epoch 719: Val Loss = 1.1715, Val Accuracy = 88.77%
# Epoch 720: Val Loss = 1.1705, Val Accuracy = 88.64%
# Epoch 721: Val Loss = 1.1719, Val Accuracy = 88.64%
# Epoch 722: Val Loss = 1.1714, Val Accuracy = 88.64%
# Epoch 723: Val Loss = 1.1759, Val Accuracy = 88.52%
# Epoch 724: Val Loss = 1.1767, Val Accuracy = 88.52%
# Epoch 725: Val Loss = 1.1798, Val Accuracy = 88.52%
# Epoch 726: Val Loss = 1.1809, Val Accuracy = 88.52%
# Epoch 727: Val Loss = 1.1817, Val Accuracy = 88.52%
# Epoch 728: Val Loss = 1.1829, Val Accuracy = 88.40%
# Epoch 729: Val Loss = 1.1782, Val Accuracy = 88.77%
# Epoch 730: Val Loss = 1.1820, Val Accuracy = 88.40%
# Epoch 731: Val Loss = 1.1824, Val Accuracy = 88.40%
# Epoch 732: Val Loss = 1.1832, Val Accuracy = 88.40%
# Epoch 733: Val Loss = 1.1858, Val Accuracy = 88.52%
# Epoch 734: Val Loss = 1.1831, Val Accuracy = 88.77%
# Epoch 735: Val Loss = 1.1828, Val Accuracy = 88.64%
# Epoch 736: Val Loss = 1.1837, Val Accuracy = 88.64%
# Epoch 737: Val Loss = 1.1866, Val Accuracy = 88.40%
# Epoch 738: Val Loss = 1.1903, Val Accuracy = 88.64%
# Epoch 739: Val Loss = 1.1888, Val Accuracy = 88.40%
# Epoch 740: Val Loss = 1.1898, Val Accuracy = 88.40%
# Epoch 741: Val Loss = 1.1872, Val Accuracy = 88.77%
# Epoch 742: Val Loss = 1.1866, Val Accuracy = 88.64%
# Epoch 743: Val Loss = 1.1905, Val Accuracy = 88.40%
# Epoch 744: Val Loss = 1.1935, Val Accuracy = 88.52%
# Epoch 745: Val Loss = 1.1917, Val Accuracy = 88.52%
# Epoch 746: Val Loss = 1.1874, Val Accuracy = 88.64%
# Epoch 747: Val Loss = 1.1912, Val Accuracy = 88.77%
# Epoch 748: Val Loss = 1.1913, Val Accuracy = 88.64%
# Epoch 749: Val Loss = 1.1932, Val Accuracy = 88.77%
# Epoch 750: Val Loss = 1.1949, Val Accuracy = 88.52%
# Epoch 751: Val Loss = 1.1943, Val Accuracy = 88.64%
# Epoch 752: Val Loss = 1.1932, Val Accuracy = 88.64%
# Epoch 753: Val Loss = 1.1953, Val Accuracy = 88.77%
# Epoch 754: Val Loss = 1.1988, Val Accuracy = 88.52%
# Epoch 755: Val Loss = 1.1973, Val Accuracy = 88.64%
# Epoch 756: Val Loss = 1.2012, Val Accuracy = 88.64%
# Epoch 757: Val Loss = 1.2022, Val Accuracy = 88.52%
# Epoch 758: Val Loss = 1.2064, Val Accuracy = 88.64%
# Epoch 759: Val Loss = 1.2095, Val Accuracy = 88.52%
# Epoch 760: Val Loss = 1.2097, Val Accuracy = 88.52%
# Epoch 761: Val Loss = 1.2057, Val Accuracy = 88.52%
# Epoch 762: Val Loss = 1.2058, Val Accuracy = 88.64%
# Epoch 763: Val Loss = 1.2042, Val Accuracy = 88.52%
# Epoch 764: Val Loss = 1.2033, Val Accuracy = 88.64%
# Epoch 765: Val Loss = 1.2059, Val Accuracy = 88.52%
# Epoch 766: Val Loss = 1.2073, Val Accuracy = 88.52%
# Epoch 767: Val Loss = 1.2078, Val Accuracy = 88.77%
# Epoch 768: Val Loss = 1.2116, Val Accuracy = 88.52%
# Epoch 769: Val Loss = 1.2091, Val Accuracy = 88.52%
# Epoch 770: Val Loss = 1.2075, Val Accuracy = 88.40%
# Epoch 771: Val Loss = 1.2084, Val Accuracy = 88.64%
# Epoch 772: Val Loss = 1.2146, Val Accuracy = 88.52%
# Epoch 773: Val Loss = 1.2143, Val Accuracy = 88.52%
# Epoch 774: Val Loss = 1.2116, Val Accuracy = 88.52%
# Epoch 775: Val Loss = 1.2131, Val Accuracy = 88.52%
# Epoch 776: Val Loss = 1.2141, Val Accuracy = 88.64%
# Epoch 777: Val Loss = 1.2133, Val Accuracy = 88.64%
# Epoch 778: Val Loss = 1.2151, Val Accuracy = 88.64%
# Epoch 779: Val Loss = 1.2144, Val Accuracy = 88.64%
# Epoch 780: Val Loss = 1.2154, Val Accuracy = 88.52%
# Epoch 781: Val Loss = 1.2164, Val Accuracy = 88.52%
# Epoch 782: Val Loss = 1.2151, Val Accuracy = 88.52%
# Epoch 783: Val Loss = 1.2167, Val Accuracy = 88.64%
# Epoch 784: Val Loss = 1.2187, Val Accuracy = 88.64%
# Epoch 785: Val Loss = 1.2229, Val Accuracy = 88.64%
# Epoch 786: Val Loss = 1.2275, Val Accuracy = 88.52%
# Epoch 787: Val Loss = 1.2292, Val Accuracy = 88.52%
# Epoch 788: Val Loss = 1.2267, Val Accuracy = 88.64%
# Epoch 789: Val Loss = 1.2238, Val Accuracy = 88.52%
# Epoch 790: Val Loss = 1.2227, Val Accuracy = 88.64%
# Epoch 791: Val Loss = 1.2232, Val Accuracy = 88.64%
# Epoch 792: Val Loss = 1.2238, Val Accuracy = 88.64%
# Epoch 793: Val Loss = 1.2252, Val Accuracy = 88.64%
# Epoch 794: Val Loss = 1.2232, Val Accuracy = 88.52%
# Epoch 795: Val Loss = 1.2236, Val Accuracy = 88.64%
# Epoch 796: Val Loss = 1.2273, Val Accuracy = 88.64%
# Epoch 797: Val Loss = 1.2295, Val Accuracy = 88.52%
# Epoch 798: Val Loss = 1.2308, Val Accuracy = 88.64%
# Epoch 799: Val Loss = 1.2316, Val Accuracy = 88.52%
# Epoch 800: Val Loss = 1.2319, Val Accuracy = 88.52%
# Epoch 801: Val Loss = 1.2275, Val Accuracy = 88.64%
# Epoch 802: Val Loss = 1.2295, Val Accuracy = 88.64%
# Epoch 803: Val Loss = 1.2280, Val Accuracy = 88.64%
# Epoch 804: Val Loss = 1.2276, Val Accuracy = 88.64%
# Epoch 805: Val Loss = 1.2313, Val Accuracy = 88.64%
# Epoch 806: Val Loss = 1.2327, Val Accuracy = 88.64%
# Epoch 807: Val Loss = 1.2336, Val Accuracy = 88.64%
# Epoch 808: Val Loss = 1.2358, Val Accuracy = 88.64%
# Epoch 809: Val Loss = 1.2360, Val Accuracy = 88.64%
# Epoch 810: Val Loss = 1.2398, Val Accuracy = 88.64%
# Epoch 811: Val Loss = 1.2358, Val Accuracy = 88.64%
# Epoch 812: Val Loss = 1.2369, Val Accuracy = 88.64%
# Epoch 813: Val Loss = 1.2390, Val Accuracy = 88.64%
# Epoch 814: Val Loss = 1.2393, Val Accuracy = 88.64%
# Epoch 815: Val Loss = 1.2387, Val Accuracy = 88.64%
# Epoch 816: Val Loss = 1.2390, Val Accuracy = 88.64%
# Epoch 817: Val Loss = 1.2366, Val Accuracy = 88.64%
# Epoch 818: Val Loss = 1.2383, Val Accuracy = 88.64%
# Epoch 819: Val Loss = 1.2390, Val Accuracy = 88.52%
# Epoch 820: Val Loss = 1.2404, Val Accuracy = 88.64%
# Epoch 821: Val Loss = 1.2389, Val Accuracy = 88.64%
# Epoch 822: Val Loss = 1.2413, Val Accuracy = 88.64%
# Epoch 823: Val Loss = 1.2414, Val Accuracy = 88.77%
# Epoch 824: Val Loss = 1.2479, Val Accuracy = 88.52%
# Epoch 825: Val Loss = 1.2431, Val Accuracy = 88.52%
# Epoch 826: Val Loss = 1.2467, Val Accuracy = 88.64%
# Epoch 827: Val Loss = 1.2468, Val Accuracy = 88.64%
# Epoch 828: Val Loss = 1.2486, Val Accuracy = 88.64%
# Epoch 829: Val Loss = 1.2481, Val Accuracy = 88.64%
# Epoch 830: Val Loss = 1.2442, Val Accuracy = 88.64%
# Epoch 831: Val Loss = 1.2487, Val Accuracy = 88.64%
# Epoch 832: Val Loss = 1.2492, Val Accuracy = 88.64%
# Epoch 833: Val Loss = 1.2538, Val Accuracy = 88.52%
# Epoch 834: Val Loss = 1.2546, Val Accuracy = 88.52%
# Epoch 835: Val Loss = 1.2581, Val Accuracy = 88.52%
# Epoch 836: Val Loss = 1.2617, Val Accuracy = 88.64%
# Epoch 837: Val Loss = 1.2614, Val Accuracy = 88.52%
# Epoch 838: Val Loss = 1.2556, Val Accuracy = 88.64%
# Epoch 839: Val Loss = 1.2544, Val Accuracy = 88.64%
# Epoch 840: Val Loss = 1.2557, Val Accuracy = 88.64%
# Epoch 841: Val Loss = 1.2551, Val Accuracy = 88.64%
# Epoch 842: Val Loss = 1.2564, Val Accuracy = 88.64%
# Epoch 843: Val Loss = 1.2582, Val Accuracy = 88.64%
# Epoch 844: Val Loss = 1.2561, Val Accuracy = 88.64%
# Epoch 845: Val Loss = 1.2604, Val Accuracy = 88.64%
# Epoch 846: Val Loss = 1.2641, Val Accuracy = 88.40%
# Epoch 847: Val Loss = 1.2642, Val Accuracy = 88.40%
# Epoch 848: Val Loss = 1.2611, Val Accuracy = 88.64%
# Epoch 849: Val Loss = 1.2618, Val Accuracy = 88.64%
# Epoch 850: Val Loss = 1.2647, Val Accuracy = 88.52%
# Epoch 851: Val Loss = 1.2640, Val Accuracy = 88.64%
# Epoch 852: Val Loss = 1.2633, Val Accuracy = 88.64%
# Epoch 853: Val Loss = 1.2641, Val Accuracy = 88.64%
# Epoch 854: Val Loss = 1.2643, Val Accuracy = 88.64%
# Epoch 855: Val Loss = 1.2652, Val Accuracy = 88.64%
# Epoch 856: Val Loss = 1.2647, Val Accuracy = 88.64%
# Epoch 857: Val Loss = 1.2636, Val Accuracy = 88.52%
# Epoch 858: Val Loss = 1.2649, Val Accuracy = 88.64%
# Epoch 859: Val Loss = 1.2709, Val Accuracy = 88.64%
# Epoch 860: Val Loss = 1.2712, Val Accuracy = 88.64%
# Epoch 861: Val Loss = 1.2670, Val Accuracy = 88.64%
# Epoch 862: Val Loss = 1.2667, Val Accuracy = 88.52%
# Epoch 863: Val Loss = 1.2643, Val Accuracy = 88.77%
# Epoch 864: Val Loss = 1.2678, Val Accuracy = 88.64%
# Epoch 865: Val Loss = 1.2717, Val Accuracy = 88.64%
# Epoch 866: Val Loss = 1.2736, Val Accuracy = 88.64%
# Epoch 867: Val Loss = 1.2771, Val Accuracy = 88.40%
# Epoch 868: Val Loss = 1.2747, Val Accuracy = 88.64%
# Epoch 869: Val Loss = 1.2742, Val Accuracy = 88.64%
# Epoch 870: Val Loss = 1.2734, Val Accuracy = 88.64%
# Epoch 871: Val Loss = 1.2754, Val Accuracy = 88.64%
# Epoch 872: Val Loss = 1.2772, Val Accuracy = 88.64%
# Epoch 873: Val Loss = 1.2769, Val Accuracy = 88.64%
# Epoch 874: Val Loss = 1.2778, Val Accuracy = 88.64%
# Epoch 875: Val Loss = 1.2799, Val Accuracy = 88.64%
# Epoch 876: Val Loss = 1.2760, Val Accuracy = 88.52%
# Epoch 877: Val Loss = 1.2771, Val Accuracy = 88.64%
# Epoch 878: Val Loss = 1.2773, Val Accuracy = 88.52%
# Epoch 879: Val Loss = 1.2791, Val Accuracy = 88.64%
# Epoch 880: Val Loss = 1.2814, Val Accuracy = 88.64%
# Epoch 881: Val Loss = 1.2800, Val Accuracy = 88.52%
# Epoch 882: Val Loss = 1.2776, Val Accuracy = 88.64%
# Epoch 883: Val Loss = 1.2836, Val Accuracy = 88.64%
# Epoch 884: Val Loss = 1.2854, Val Accuracy = 88.64%
# Epoch 885: Val Loss = 1.2807, Val Accuracy = 88.52%
# Epoch 886: Val Loss = 1.2834, Val Accuracy = 88.64%
# Epoch 887: Val Loss = 1.2840, Val Accuracy = 88.64%
# Epoch 888: Val Loss = 1.2855, Val Accuracy = 88.64%
# Epoch 889: Val Loss = 1.2894, Val Accuracy = 88.52%
# Epoch 890: Val Loss = 1.2885, Val Accuracy = 88.64%
# Epoch 891: Val Loss = 1.2894, Val Accuracy = 88.64%
# Epoch 892: Val Loss = 1.2879, Val Accuracy = 88.52%
# Epoch 893: Val Loss = 1.2868, Val Accuracy = 88.52%
# Epoch 894: Val Loss = 1.2879, Val Accuracy = 88.52%
# Epoch 895: Val Loss = 1.2887, Val Accuracy = 88.52%
# Epoch 896: Val Loss = 1.2901, Val Accuracy = 88.64%
# Epoch 897: Val Loss = 1.2913, Val Accuracy = 88.64%
# Epoch 898: Val Loss = 1.2893, Val Accuracy = 88.52%
# Epoch 899: Val Loss = 1.2943, Val Accuracy = 88.64%
# Epoch 900: Val Loss = 1.2954, Val Accuracy = 88.77%
# Epoch 901: Val Loss = 1.2948, Val Accuracy = 88.64%
# Epoch 902: Val Loss = 1.2949, Val Accuracy = 88.64%
# Epoch 903: Val Loss = 1.2999, Val Accuracy = 88.52%
# Epoch 904: Val Loss = 1.3003, Val Accuracy = 88.52%
# Epoch 905: Val Loss = 1.2947, Val Accuracy = 88.52%
# Epoch 906: Val Loss = 1.2997, Val Accuracy = 88.64%
# Epoch 907: Val Loss = 1.2981, Val Accuracy = 88.64%
# Epoch 908: Val Loss = 1.2970, Val Accuracy = 88.52%
# Epoch 909: Val Loss = 1.3011, Val Accuracy = 88.52%
# Epoch 910: Val Loss = 1.3017, Val Accuracy = 88.64%
# Epoch 911: Val Loss = 1.3004, Val Accuracy = 88.64%
# Epoch 912: Val Loss = 1.3025, Val Accuracy = 88.77%
# Epoch 913: Val Loss = 1.3042, Val Accuracy = 88.52%
# Epoch 914: Val Loss = 1.3027, Val Accuracy = 88.64%
# Epoch 915: Val Loss = 1.3008, Val Accuracy = 88.52%
# Epoch 916: Val Loss = 1.3073, Val Accuracy = 88.52%
# Epoch 917: Val Loss = 1.3096, Val Accuracy = 88.52%
# Epoch 918: Val Loss = 1.3115, Val Accuracy = 88.40%
# Epoch 919: Val Loss = 1.3097, Val Accuracy = 88.52%
# Epoch 920: Val Loss = 1.3091, Val Accuracy = 88.64%
# Epoch 921: Val Loss = 1.3076, Val Accuracy = 88.64%
# Epoch 922: Val Loss = 1.3092, Val Accuracy = 88.64%
# Epoch 923: Val Loss = 1.3067, Val Accuracy = 88.52%
# Epoch 924: Val Loss = 1.3093, Val Accuracy = 88.64%
# Epoch 925: Val Loss = 1.3103, Val Accuracy = 88.64%
# Epoch 926: Val Loss = 1.3145, Val Accuracy = 88.52%
# Epoch 927: Val Loss = 1.3170, Val Accuracy = 88.64%
# Epoch 928: Val Loss = 1.3124, Val Accuracy = 88.64%
# Epoch 929: Val Loss = 1.3099, Val Accuracy = 88.52%
# Epoch 930: Val Loss = 1.3148, Val Accuracy = 88.52%
# Epoch 931: Val Loss = 1.3107, Val Accuracy = 88.52%
# Epoch 932: Val Loss = 1.3119, Val Accuracy = 88.64%
# Epoch 933: Val Loss = 1.3116, Val Accuracy = 88.52%
# Epoch 934: Val Loss = 1.3147, Val Accuracy = 88.64%
# Epoch 935: Val Loss = 1.3121, Val Accuracy = 88.64%
# Epoch 936: Val Loss = 1.3152, Val Accuracy = 88.64%
# Epoch 937: Val Loss = 1.3161, Val Accuracy = 88.64%
# Epoch 938: Val Loss = 1.3181, Val Accuracy = 88.64%
# Epoch 939: Val Loss = 1.3181, Val Accuracy = 88.64%
# Epoch 940: Val Loss = 1.3170, Val Accuracy = 88.52%
# Epoch 941: Val Loss = 1.3167, Val Accuracy = 88.52%
# Epoch 942: Val Loss = 1.3171, Val Accuracy = 88.52%
# Epoch 943: Val Loss = 1.3185, Val Accuracy = 88.52%
# Epoch 944: Val Loss = 1.3188, Val Accuracy = 88.52%
# Epoch 945: Val Loss = 1.3237, Val Accuracy = 88.52%
# Epoch 946: Val Loss = 1.3235, Val Accuracy = 88.64%
# Epoch 947: Val Loss = 1.3193, Val Accuracy = 88.52%
# Epoch 948: Val Loss = 1.3201, Val Accuracy = 88.52%
# Epoch 949: Val Loss = 1.3231, Val Accuracy = 88.64%
# Epoch 950: Val Loss = 1.3262, Val Accuracy = 88.64%
# Epoch 951: Val Loss = 1.3354, Val Accuracy = 88.64%
# Epoch 952: Val Loss = 1.3295, Val Accuracy = 88.52%
# Epoch 953: Val Loss = 1.3299, Val Accuracy = 88.52%
# Epoch 954: Val Loss = 1.3271, Val Accuracy = 88.64%
# Epoch 955: Val Loss = 1.3295, Val Accuracy = 88.52%
# Epoch 956: Val Loss = 1.3296, Val Accuracy = 88.52%
# Epoch 957: Val Loss = 1.3304, Val Accuracy = 88.52%
# Epoch 958: Val Loss = 1.3273, Val Accuracy = 88.52%
# Epoch 959: Val Loss = 1.3296, Val Accuracy = 88.64%
# Epoch 960: Val Loss = 1.3328, Val Accuracy = 88.52%
# Epoch 961: Val Loss = 1.3356, Val Accuracy = 88.52%
# Epoch 962: Val Loss = 1.3328, Val Accuracy = 88.52%
# Epoch 963: Val Loss = 1.3289, Val Accuracy = 88.52%
# Epoch 964: Val Loss = 1.3319, Val Accuracy = 88.52%
# Epoch 965: Val Loss = 1.3337, Val Accuracy = 88.52%
# Epoch 966: Val Loss = 1.3332, Val Accuracy = 88.52%
# Epoch 967: Val Loss = 1.3369, Val Accuracy = 88.64%
# Epoch 968: Val Loss = 1.3351, Val Accuracy = 88.64%
# Epoch 969: Val Loss = 1.3369, Val Accuracy = 88.64%
# Epoch 970: Val Loss = 1.3381, Val Accuracy = 88.52%
# Epoch 971: Val Loss = 1.3387, Val Accuracy = 88.52%
# Epoch 972: Val Loss = 1.3379, Val Accuracy = 88.52%
# Epoch 973: Val Loss = 1.3404, Val Accuracy = 88.52%
# Epoch 974: Val Loss = 1.3378, Val Accuracy = 88.52%
# Epoch 975: Val Loss = 1.3403, Val Accuracy = 88.52%
# Epoch 976: Val Loss = 1.3482, Val Accuracy = 88.64%
# Epoch 977: Val Loss = 1.3451, Val Accuracy = 88.52%
# Epoch 978: Val Loss = 1.3411, Val Accuracy = 88.52%
# Epoch 979: Val Loss = 1.3412, Val Accuracy = 88.52%
# Epoch 980: Val Loss = 1.3420, Val Accuracy = 88.52%
# Epoch 981: Val Loss = 1.3422, Val Accuracy = 88.52%
# Epoch 982: Val Loss = 1.3396, Val Accuracy = 88.64%
# Epoch 983: Val Loss = 1.3452, Val Accuracy = 88.52%
# Epoch 984: Val Loss = 1.3439, Val Accuracy = 88.52%
# Epoch 985: Val Loss = 1.3449, Val Accuracy = 88.52%
# Epoch 986: Val Loss = 1.3459, Val Accuracy = 88.52%
# Epoch 987: Val Loss = 1.3451, Val Accuracy = 88.52%
# Epoch 988: Val Loss = 1.3466, Val Accuracy = 88.52%
# Epoch 989: Val Loss = 1.3484, Val Accuracy = 88.52%
# Epoch 990: Val Loss = 1.3485, Val Accuracy = 88.52%
# Epoch 991: Val Loss = 1.3498, Val Accuracy = 88.40%
# Epoch 992: Val Loss = 1.3475, Val Accuracy = 88.52%
# Epoch 993: Val Loss = 1.3541, Val Accuracy = 88.52%
# Epoch 994: Val Loss = 1.3505, Val Accuracy = 88.52%
# Epoch 995: Val Loss = 1.3523, Val Accuracy = 88.52%
# Epoch 996: Val Loss = 1.3480, Val Accuracy = 88.64%
# Epoch 997: Val Loss = 1.3526, Val Accuracy = 88.52%
# Epoch 998: Val Loss = 1.3543, Val Accuracy = 88.40%
# Epoch 999: Val Loss = 1.3537, Val Accuracy = 88.52%

# %%
import matplotlib.pyplot as plt

plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Instantiate the model, optimizer, and loss function
model = EMGModel()
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()
train_losses = []
val_losses = []
# Training loop
for epoch in range(70):
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad()  # Reset gradients
        output = model(data)  # Forward pass
        loss = criterion(output, target) # Calculate loss, convert target to long
        loss.backward()  # Backpropagate
        optimizer.step()  # Update weights

    # Validation

    val_loss, val_accuracy = validate(model, test_loader, criterion)
    print(f"Epoch {epoch}: Val Loss = {val_loss:.4f}, Val Accuracy = {val_accuracy:.2f}%")

    # Append losses
    train_losses.append(loss.item()) # Append training loss for current batch
    val_losses.append(val_loss)

plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

torch.serialization.add_safe_globals([EMGModel])
# Out:
# Epoch 0: Val Loss = 1.5911, Val Accuracy = 31.38%
# Epoch 1: Val Loss = 1.5479, Val Accuracy = 24.91%
# Epoch 2: Val Loss = 1.4691, Val Accuracy = 49.21%
# Epoch 3: Val Loss = 1.3307, Val Accuracy = 60.07%
# Epoch 4: Val Loss = 1.1340, Val Accuracy = 66.91%
# Epoch 5: Val Loss = 0.9491, Val Accuracy = 72.65%
# Epoch 6: Val Loss = 0.8006, Val Accuracy = 82.30%
# Epoch 7: Val Loss = 0.6946, Val Accuracy = 82.30%
# Epoch 8: Val Loss = 0.5985, Val Accuracy = 82.05%
# Epoch 9: Val Loss = 0.5337, Val Accuracy = 84.25%
# Epoch 10: Val Loss = 0.4883, Val Accuracy = 84.13%
# Epoch 11: Val Loss = 0.4565, Val Accuracy = 85.59%
# Epoch 12: Val Loss = 0.4313, Val Accuracy = 85.23%
# Epoch 13: Val Loss = 0.4149, Val Accuracy = 85.71%
# Epoch 14: Val Loss = 0.3981, Val Accuracy = 86.94%
# Epoch 15: Val Loss = 0.3869, Val Accuracy = 86.20%
# Epoch 16: Val Loss = 0.3763, Val Accuracy = 88.03%
# Epoch 17: Val Loss = 0.3713, Val Accuracy = 88.28%
# Epoch 18: Val Loss = 0.3694, Val Accuracy = 88.40%
# Epoch 19: Val Loss = 0.3595, Val Accuracy = 88.28%
# Epoch 20: Val Loss = 0.3611, Val Accuracy = 88.16%
# Epoch 21: Val Loss = 0.3446, Val Accuracy = 88.28%
# Epoch 22: Val Loss = 0.3405, Val Accuracy = 88.64%
# Epoch 23: Val Loss = 0.3367, Val Accuracy = 88.64%
# Epoch 24: Val Loss = 0.3343, Val Accuracy = 89.13%
# Epoch 25: Val Loss = 0.3306, Val Accuracy = 88.52%
# Epoch 26: Val Loss = 0.3308, Val Accuracy = 89.26%
# Epoch 27: Val Loss = 0.3320, Val Accuracy = 89.26%
# Epoch 28: Val Loss = 0.3270, Val Accuracy = 88.52%
# Epoch 29: Val Loss = 0.3238, Val Accuracy = 88.77%
# Epoch 30: Val Loss = 0.3300, Val Accuracy = 88.52%
# Epoch 31: Val Loss = 0.3324, Val Accuracy = 89.01%
# Epoch 32: Val Loss = 0.3229, Val Accuracy = 89.62%
# Epoch 33: Val Loss = 0.3175, Val Accuracy = 88.77%
# Epoch 34: Val Loss = 0.3227, Val Accuracy = 89.01%
# Epoch 35: Val Loss = 0.3255, Val Accuracy = 89.26%
# Epoch 36: Val Loss = 0.3287, Val Accuracy = 89.26%
# Epoch 37: Val Loss = 0.3128, Val Accuracy = 89.38%
# Epoch 38: Val Loss = 0.3141, Val Accuracy = 89.26%
# Epoch 39: Val Loss = 0.3090, Val Accuracy = 89.13%
# Epoch 40: Val Loss = 0.3205, Val Accuracy = 89.50%
# Epoch 41: Val Loss = 0.3082, Val Accuracy = 89.99%
# Epoch 42: Val Loss = 0.3103, Val Accuracy = 89.13%
# Epoch 43: Val Loss = 0.3270, Val Accuracy = 89.38%
# Epoch 44: Val Loss = 0.3075, Val Accuracy = 89.50%
# Epoch 45: Val Loss = 0.3012, Val Accuracy = 89.13%
# Epoch 46: Val Loss = 0.3051, Val Accuracy = 89.50%
# Epoch 47: Val Loss = 0.3270, Val Accuracy = 89.13%
# Epoch 48: Val Loss = 0.2987, Val Accuracy = 90.11%
# Epoch 49: Val Loss = 0.2940, Val Accuracy = 89.01%
# Epoch 50: Val Loss = 0.3454, Val Accuracy = 88.89%
# Epoch 51: Val Loss = 0.3084, Val Accuracy = 89.74%
# Epoch 52: Val Loss = 0.2894, Val Accuracy = 88.89%
# Epoch 53: Val Loss = 0.2883, Val Accuracy = 88.77%
# Epoch 54: Val Loss = 0.2934, Val Accuracy = 89.99%
# Epoch 55: Val Loss = 0.3311, Val Accuracy = 89.01%
# Epoch 56: Val Loss = 0.3030, Val Accuracy = 90.11%
# Epoch 57: Val Loss = 0.2836, Val Accuracy = 89.50%
# Epoch 58: Val Loss = 0.2881, Val Accuracy = 90.48%
# Epoch 59: Val Loss = 0.2839, Val Accuracy = 89.26%
# Epoch 60: Val Loss = 0.3075, Val Accuracy = 89.62%
# Epoch 61: Val Loss = 0.2776, Val Accuracy = 89.26%
# Epoch 62: Val Loss = 0.2744, Val Accuracy = 89.13%
# Epoch 63: Val Loss = 0.2907, Val Accuracy = 90.60%
# Epoch 64: Val Loss = 0.2992, Val Accuracy = 90.23%
# Epoch 65: Val Loss = 0.2744, Val Accuracy = 89.62%
# Epoch 66: Val Loss = 0.2709, Val Accuracy = 89.62%
# Epoch 67: Val Loss = 0.2801, Val Accuracy = 89.99%
# Epoch 68: Val Loss = 0.2711, Val Accuracy = 89.62%
# Epoch 69: Val Loss = 0.2701, Val Accuracy = 89.74%

# %%
torch.save(model, '/content/drive/MyDrive/EMG hand gestures dataset/model.pth')

# %%
def test_model(model, test_loader):
    model.eval()  # Set the model to evaluation mode
    correct = 0
    total = 0
    with torch.no_grad():  # Disable gradient calculation
        for data, target in test_loader:
            output = model(data)
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == torch.argmax(target, dim=1)).sum().item()

    accuracy = 100 * correct / total
    print(f"Test Accuracy: {accuracy:.2f}%")

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def test_model_with_confusion_matrix(model, test_loader):
    model.eval()  # Set the model to evaluation mode
    all_predicted = []
    all_targets = []
    with torch.no_grad():  # Disable gradient calculation
        for data, target in test_loader:
            output = model(data)
            _, predicted = torch.max(output.data, 1)
            all_predicted.extend(predicted.cpu().numpy())
            all_targets.extend(torch.argmax(target, dim=1).cpu().numpy())

    # Generate confusion matrix
    cm = confusion_matrix(all_targets, all_predicted)

    # Normalize confusion matrix to percentages
    cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

    # Display confusion matrix using seaborn heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm_percent, annot=True, fmt=".1f", cmap="Blues")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix (Percentages)")
    plt.show()

    return cm # Return the original confusion matrix (with raw counts)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def test_model_with_confusion_matrix_original(model, test_loader):
    model.eval()  # Set the model to evaluation mode
    all_predicted = []
    all_targets = []
    with torch.no_grad():  # Disable gradient calculation
        for data, target in test_loader:
            output = model(data)
            _, predicted = torch.max(output.data, 1)
            all_predicted.extend(predicted.cpu().numpy())
            all_targets.extend(torch.argmax(target, dim=1).cpu().numpy())

    # Generate confusion matrix
    cm = confusion_matrix(all_targets, all_predicted)

    # Display confusion matrix using seaborn heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")  # fmt="d" for integers
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix (Raw Counts)")
    plt.show()

    return cm  # Return the original confusion matrix (with raw counts)

# %%
torch.serialization.add_safe_globals([EMGModel, nn.Linear, nn.Tanh, nn.LSTM])

# %%
# Load the saved model
#model = torch.load('/content/drive/MyDrive/EMG hand gestures dataset/model.pth')

# %%
test_model(model, test_loader)
# Out:
# Test Accuracy: 89.74%

# %%
#Call the function with your model and test_loader
cm = test_model_with_confusion_matrix_original(model, test_loader)

# %%
#Call the function with your model and test_loader
cm = test_model_with_confusion_matrix(model, test_loader)

# %%
def count_parameters(model):
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        total_params+=param
        print(f"Layer: {name} | Parameters: {param}")
    print(f"----------------------------")
    print(f"Total trainable parameters: {total_params}")


def model_summary(model):
    """Prints a summary of the model's architecture and parameters."""
    print(model)  # Print model architecture
    count_parameters(model)  # Print per-layer and total parameter counts

model_summary(model)
# Out:
# EMGModel(
#   (fc1): Linear(in_features=800, out_features=32, bias=True)
#   (tanh1): Tanh()
#   (lstm): LSTM(32, 16, batch_first=True)
#   (fc2): Linear(in_features=16, out_features=32, bias=True)
#   (tanh2): Tanh()
#   (fc3): Linear(in_features=32, out_features=5, bias=True)
#   (softmax): Softmax(dim=1)
# )
# Layer: fc1.weight | Parameters: 25600
# Layer: fc1.bias | Parameters: 32
# Layer: lstm.weight_ih_l0 | Parameters: 2048
# Layer: lstm.weight_hh_l0 | Parameters: 1024
# Layer: lstm.bias_ih_l0 | Parameters: 64
# Layer: lstm.bias_hh_l0 | Parameters: 64
# Layer: fc2.weight | Parameters: 512
# Layer: fc2.bias | Parameters: 32
# Layer: fc3.weight | Parameters: 160
# Layer: fc3.bias | Parameters: 5
# ----------------------------
# Total trainable parameters: 29541

# %%
import sys
import numpy as np

def get_model_size(model):
    """Calculates the size of a PyTorch model in MB.

    Args:
        model: The PyTorch model.

    Returns:
        The size of the model in MB.
    """
    total_size = 0
    for param in model.parameters():  # Iterate over model parameters
        total_size += param.nelement() * param.element_size()

    total_size_mb = total_size / (1024 * 1024)  # Convert to MB
    return total_size_mb

# Get the model size
model_size_mb = get_model_size(model)
print(f"Model size: {model_size_mb:.2f} MB")
# Out:
# Model size: 0.11 MB
